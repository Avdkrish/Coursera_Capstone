# %% [markdown]
# # HI THERE
#  This notebook will consist of the following parts:<br>
#
#  1. Data collection<br>
#  2. Data manipulation<br>
#  3. Modeling with K-means<br>
#  4. Visualization through Folium

# %% [markdown]
# ### DATA COLLECTION

# %% [markdown]
# The primary data sources are:<br>
# 1. Tripadivsor website<br>
# 2. Geocoder using geopy<br>
# 3. Foursquare API<br>

# %%
#importing essential libraries
import numpy as np
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

#import beautiful soup
from urllib.request import urlopen
from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Using the **beautifulsoup** library we extract the top 10 destinations that one must visit in Kolkata.
# Here, you can take a look yourself<br>
# __[TripAdvisor]('https://www.tripadvisor.in/Attractions-g304558-Activities-Kolkata_Calcutta_Kolkata_District_West_Bengal.html')__

# %%
#creating url and beautifulsoup objects for web scraping
url='https://www.tripadvisor.in/Attractions-g304558-Activities-Kolkata_Calcutta_Kolkata_District_West_Bengal.html'
result=requests.get(url)
print(result.status_code)#prints 200 if the url is accesible
soup=BeautifulSoup(result.content,'html.parser')
# Out:
# 200

# %% [markdown]
# When i was accessing the geocoder, i found that some of the locations didnot return a latitude_longitude.I thought there might be some spelling mistakes in the names but found that that's not the case.So, i removed those locations using a list **geocoder_not_working**

# %%
#extraxcting the locations and converting it to a data frame
links=soup.find_all('a',class_='attractions-attraction-overview-pois-PoiInfo__name--SJ0a4')
text_list=[link.get_text() for link in links]
text_list=text_list[:13]
Top_Locations=pd.DataFrame(text_list)
Top_Locations.columns=['name']
geocoder_not_working=['Dakshineswar Kali Temple','Eco Tourism Park','College Street (Boi Para)']
Top_Locations=Top_Locations[~Top_Locations['name'].isin(geocoder_not_working)]
locations_list=Top_Locations['name'].tolist()

# %% [markdown]
# The locations with their co-ordinates are stored in a pandas DataFrame (Top_Locations) for later marking in the folium map.

# %%
#loop through each location to find their co-ordinates
lat=[]
long=[]
for ele in locations_list:
    geolocator = Nominatim(user_agent="my-application")
    address = '{}, Kolkata'.format(ele)
    geolocator = Nominatim(user_agent="my-application")
    location = geolocator.geocode(address)
    lat.append(location.latitude)
    long.append(location.longitude)

# %%
#creating a comprehensive data frame
Top_Locations['Lat']=lat
Top_Locations['Long']=long
Top_Locations
# Out:
#                       name        Lat       Long
# 0   Victoria Memorial Hall  22.545080  88.342643
# 2             Mother House  22.553101  88.363662
# 3              Park Street  22.555159  88.350117
# 5            Howrah Bridge  22.585091  88.346825
# 6             Eden Gardens  22.564588  88.342290
# 7             Science City  22.539925  88.395810
# 8               Quest Mall  22.539027  88.365656
# 10            Prinsep Ghat  22.556573  88.331418
# 11       Birla Planetarium  22.545507  88.347318
# 12              New Market  22.560119  88.356735

# %% [markdown]
# Inorder to use the geocoder from geopy library,we need the location co-ordinates of the city of Kolkata

# %%
#geocoding location in co-ordinates
address = 'Kolkata, West Bengal'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Kolkata are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Kolkata are 22.5414392, 88.3517606171429.

# %% [markdown]
# Setting up FourSquare credentials:

# %%
CLIENT_ID = 'LOGKHYI2TF0NAO3SONDBWJWAC5J3MIHLYVMFRUX4DOFXDBY0' # your Foursquare ID
CLIENT_SECRET = 'VHXL2Q0JRYHHHCZ0KEXJRIAJO5MJIPWCFCGDYB0GVECXUV5V' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: LOGKHYI2TF0NAO3SONDBWJWAC5J3MIHLYVMFRUX4DOFXDBY0
# CLIENT_SECRET:VHXL2Q0JRYHHHCZ0KEXJRIAJO5MJIPWCFCGDYB0GVECXUV5V

# %%
LIMIT = 1000 # limit of number of venues returned by Foursquare API
radius = 10000 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=LOGKHYI2TF0NAO3SONDBWJWAC5J3MIHLYVMFRUX4DOFXDBY0&client_secret=VHXL2Q0JRYHHHCZ0KEXJRIAJO5MJIPWCFCGDYB0GVECXUV5V&v=20180605&ll=22.5414392,88.3517606171429&radius=10000&limit=1000'

# %%
#getting the results for the API Explore query
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5df09664b4b684001bb5885c'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Kolkata',
#   'headerFullLocation': 'Kolkata',
#   'headerLocationGranularity': 'city',
#   'totalResults': 165,
#   'suggestedBounds': {'ne': {'lat': 22.63143929000009,
#     'lng': 88.44902329029748},
#    'sw': {'lat': 22.45143910999991, 'lng': 88.25449794398833}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d43fd7b4e5d370413f4e593',
#        'name': 'The Blue Poppy',
#        'location': {'address': '4/1, Middleton St',
#         'lat': 22.548543210513543,
#         'lng': 88.35135293517806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.548543210513543,
#           'lng': 88.35135293517806}],
#         'distance': 791,
#         'postalCode': '700071',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['4/1, Middleton St',
#          'Kolkata 700071',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d43fd7b4e5d370413f4e593-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d050f03347da1cd0d012f8f',
#        'name': 'Jai Hind Dhaba',
#        'location': {'address': '41/1A, Sarat Bose Rd',
#         'lat': 22.533109206899187,
#         'lng': 88.35326750112607,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.533109206899187,
#           'lng': 88.35326750112607}],
#         'distance': 940,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['41/1A, Sarat Bose Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfe1',
#          'name': 'Dhaba',
#          'pluralName': 'Dhabas',
#          'shortName': 'Dhaba',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d050f03347da1cd0d012f8f-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0218258ef2c9b66d9c16fc',
#        'name': 'Victoria Memorial',
#        'location': {'address': "1, Queen's Way",
#         'lat': 22.545844129353117,
#         'lng': 88.34289036897952,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.545844129353117,
#           'lng': 88.34289036897952}],
#         'distance': 1035,
#         'postalCode': '700071',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ["1, Queen's Way",
#          'Kolkata 700071',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0218258ef2c9b66d9c16fc-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d1c6d5a7e10a35dcb13ff82',
#        'name': "Balwant Singh's Eating House",
#        'location': {'address': '10/B, Harish Mukherjee Rd',
#         'lat': 22.537714013534053,
#         'lng': 88.34421978219828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.537714013534053,
#           'lng': 88.34421978219828}],
#         'distance': 879,
#         'postalCode': '700025',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['10/B, Harish Mukherjee Rd',
#          'Kolkata 700025',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfe1',
#          'name': 'Dhaba',
#          'pluralName': 'Dhabas',
#          'shortName': 'Dhaba',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d1c6d5a7e10a35dcb13ff82-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c284edefe6e2d7f5417533c',
#        'name': 'Peter Cat',
#        'location': {'address': '18, Park St',
#         'lat': 22.552364717378428,
#         'lng': 88.35254430770874,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.552364717378428,
#           'lng': 88.35254430770874}],
#         'distance': 1218,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['18, Park St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c284edefe6e2d7f5417533c-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a0ee8bbc676b0b24449d5',
#        'name': 'Oh! Calcutta',
#        'location': {'address': 'Forum Mall, 10/3 Elgin Rd',
#         'lat': 22.53835691442138,
#         'lng': 88.35140625118088,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53835691442138,
#           'lng': 88.35140625118088}],
#         'distance': 345,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Forum Mall, 10/3 Elgin Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff5',
#          'name': 'Bengali Restaurant',
#          'pluralName': 'Bengali Restaurants',
#          'shortName': 'Bengali',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0a0ee8bbc676b0b24449d5-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '534fda5e498e8696570687b8',
#        'name': 'Yauatcha',
#        'location': {'address': 'Quest Mall',
#         'lat': 22.539091355187338,
#         'lng': 88.36557324255233,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539091355187338,
#           'lng': 88.36557324255233}],
#         'distance': 1443,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Quest Mall',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-534fda5e498e8696570687b8-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ee506ee4b0f01d13d51008',
#        'name': 'Maidan',
#        'location': {'lat': 22.549906,
#         'lng': 88.344219,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.549906,
#           'lng': 88.344219}],
#         'distance': 1220,
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Kolkata', 'West Bengal', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d15f941735',
#          'name': 'Field',
#          'pluralName': 'Fields',
#          'shortName': 'Field',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/field_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50ee506ee4b0f01d13d51008-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4c107ee1ec6dcbad95d475',
#        'name': 'The Oberoi Grand',
#        'location': {'address': '15, Jawaharlal Nehru Rd',
#         'lat': 22.56174943131244,
#         'lng': 88.35159438973265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.56174943131244,
#           'lng': 88.35159438973265}],
#         'distance': 2260,
#         'postalCode': '700013',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['15, Jawaharlal Nehru Rd',
#          'Kolkata 700013',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4c107ee1ec6dcbad95d475-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d70225a9aac224bd12337ed',
#        'name': 'Nocturne',
#        'location': {'address': '31, Shakespeare Sarani',
#         'lat': 22.545077960882093,
#         'lng': 88.3573835632132,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.545077960882093,
#           'lng': 88.3573835632132}],
#         'distance': 705,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['31, Shakespeare Sarani',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d70225a9aac224bd12337ed-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd1cf255e0cce72fd05a284',
#        'name': 'Taj Bengal',
#        'location': {'address': '34B, Belvedere Rd',
#         'lat': 22.537459297849168,
#         'lng': 88.33406559589542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.537459297849168,
#           'lng': 88.33406559589542}],
#         'distance': 1872,
#         'postalCode': '700027',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['34B, Belvedere Rd',
#          'Kolkata 700027',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd1cf255e0cce72fd05a284-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5001966ae4b0444ec20e4135',
#        'name': 'The Rouge',
#        'location': {'address': '222, Acharya Jagadish Chandra Bose Rd',
#         'lat': 22.541217298910773,
#         'lng': 88.35926670939986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.541217298910773,
#           'lng': 88.35926670939986}],
#         'distance': 772,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['222, Acharya Jagadish Chandra Bose Rd',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5001966ae4b0444ec20e4135-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55e44fc0498e6b62fb94d77b',
#        'name': 'TGI Fridays',
#        'location': {'address': 'Forum Mall',
#         'lat': 22.538591688992373,
#         'lng': 88.3513984332749,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.538591688992373,
#           'lng': 88.3513984332749}],
#         'distance': 319,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Forum Mall',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55e44fc0498e6b62fb94d77b-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2c0d7a18a80bb0585fae4d',
#        'name': 'Blue & Beyond',
#        'location': {'address': 'Hotel Lindsay',
#         'lat': 22.55913129083683,
#         'lng': 88.35327973820304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55913129083683,
#           'lng': 88.35327973820304}],
#         'distance': 1975,
#         'postalCode': '700087',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Hotel Lindsay',
#          'Kolkata 700087',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e2c0d7a18a80bb0585fae4d-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4beffa4ca09076b01ea229d4',
#        'name': 'Underground',
#        'location': {'address': 'Hotel Hindusthan International',
#         'lat': 22.54129002888685,
#         'lng': 88.35062863439614,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.54129002888685,
#           'lng': 88.35062863439614}],
#         'distance': 117,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Hotel Hindusthan International',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4beffa4ca09076b01ea229d4-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc9c62b511f9521982faec7',
#        'name': 'Eden Garden',
#        'location': {'address': 'BBD Bagh',
#         'lat': 22.564541597977065,
#         'lng': 88.34329605102539,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.564541597977065,
#           'lng': 88.34329605102539}],
#         'distance': 2714,
#         'postalCode': '700021',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['BBD Bagh',
#          'Kolkata 700021',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d18a941735',
#          'name': 'Cricket Ground',
#          'pluralName': 'Cricket Grounds',
#          'shortName': 'Cricket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_cricket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc9c62b511f9521982faec7-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511b63ace4b00262d57ed073',
#        'name': 'Mithai',
#        'location': {'address': '48B, Syed Amir Ali Ave',
#         'lat': 22.53835353486725,
#         'lng': 88.36498975753784,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53835353486725,
#           'lng': 88.36498975753784}],
#         'distance': 1402,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['48B, Syed Amir Ali Ave',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfe4',
#          'name': 'Indian Sweet Shop',
#          'pluralName': 'Indian Sweet Shops',
#          'shortName': 'Indian Sweets',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-511b63ace4b00262d57ed073-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4befc8c03a002d7f386285a4',
#        'name': 'Flurys',
#        'location': {'address': '18, Park St',
#         'crossStreet': 'Sir William James Sarani',
#         'lat': 22.552786429700397,
#         'lng': 88.35262520281624,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.552786429700397,
#           'lng': 88.35262520281624}],
#         'distance': 1266,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['18, Park St (Sir William James Sarani)',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4befc8c03a002d7f386285a4-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5274b7f111d2b513631071a5',
#        'name': 'Quest Mall',
#        'location': {'address': '33, Syed Aamir Ali Ave',
#         'lat': 22.539068009925764,
#         'lng': 88.36552456686483,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539068009925764,
#           'lng': 88.36552456686483}],
#         'distance': 1439,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['33, Syed Aamir Ali Ave',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5274b7f111d2b513631071a5-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c9d100498e12bbb73fa6a4',
#        'name': 'Monkey Bar',
#        'location': {'address': '6, Camac St',
#         'lat': 22.544285918954575,
#         'lng': 88.3519599306665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.544285918954575,
#           'lng': 88.3519599306665}],
#         'distance': 317,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['6, Camac St',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c9d100498e12bbb73fa6a4-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d54ed50c6edf04d1af5bea2',
#        'name': '6 Ballygunge Place',
#        'location': {'address': '6, Ballygunge Pl',
#         'lat': 22.527711762714475,
#         'lng': 88.36867703124626,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.527711762714475,
#           'lng': 88.36867703124626}],
#         'distance': 2315,
#         'postalCode': '700019',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['6, Ballygunge Pl',
#          'Kolkata 700019',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff5',
#          'name': 'Bengali Restaurant',
#          'pluralName': 'Bengali Restaurants',
#          'shortName': 'Bengali',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d54ed50c6edf04d1af5bea2-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf3afe36c29236adc2472a2',
#        'name': 'The French Loaf',
#        'location': {'address': '2/7, Sarat Bose Rd',
#         'lat': 22.539240423448703,
#         'lng': 88.35492074489594,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539240423448703,
#           'lng': 88.35492074489594}],
#         'distance': 406,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['2/7, Sarat Bose Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf3afe36c29236adc2472a2-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e0b1e8422713e13018ee0a1',
#        'name': 'Bar-B-Q',
#        'location': {'address': '43, 47, 55, Park St',
#         'lat': 22.55312518463798,
#         'lng': 88.35262477397919,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55312518463798,
#           'lng': 88.35262477397919}],
#         'distance': 1303,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['43, 47, 55, Park St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e0b1e8422713e13018ee0a1-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '534a4e4f498e504051fbb385',
#        'name': 'Bombay Brasserie',
#        'location': {'address': '5th Floor, Quest Mall',
#         'lat': 22.53876974957041,
#         'lng': 88.3655321583331,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53876974957041,
#           'lng': 88.3655321583331}],
#         'distance': 1446,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'neighborhood': 'Ballygunge, Kolkata, West Bengal',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['5th Floor, Quest Mall',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-534a4e4f498e504051fbb385-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4beebe513686c9b69bde246e',
#        'name': 'Mocambo',
#        'location': {'address': '25B, Mirza Ghalib St',
#         'lat': 22.55320566647117,
#         'lng': 88.35329612619873,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55320566647117,
#           'lng': 88.35329612619873}],
#         'distance': 1319,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['25B, Mirza Ghalib St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4beebe513686c9b69bde246e-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da1df087aee548112fec9fe',
#        'name': 'Sonargaon',
#        'location': {'address': 'Taj Bengal',
#         'lat': 22.537544764755527,
#         'lng': 88.33421006677327,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.537544764755527,
#           'lng': 88.33421006677327}],
#         'distance': 1855,
#         'postalCode': '700027',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Taj Bengal',
#          'Kolkata 700027',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da1df087aee548112fec9fe-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbf785db083a593d77fa3e9',
#        'name': 'Aqua',
#        'location': {'address': 'The Park',
#         'crossStreet': 'at The Park hotel',
#         'lat': 22.55473429407938,
#         'lng': 88.3521798097082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55473429407938,
#           'lng': 88.3521798097082}],
#         'distance': 1480,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['The Park (at The Park hotel)',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbf785db083a593d77fa3e9-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5239ee910493e46a092f23c7',
#        'name': 'Arsalan',
#        'location': {'address': '119A, Muzaffar Ahmed St',
#         'crossStreet': 'Park St',
#         'lat': 22.553897023487213,
#         'lng': 88.35406338023041,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.553897023487213,
#           'lng': 88.35406338023041}],
#         'distance': 1406,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['119A, Muzaffar Ahmed St (Park St)',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff4',
#          'name': 'Mughlai Restaurant',
#          'pluralName': 'Mughlai Restaurants',
#          'shortName': 'Mughlai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5239ee910493e46a092f23c7-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd7482a7716469f62fb4560',
#        'name': 'Balaram Mullick & Radharaman Mullick',
#        'location': {'address': '2, Paddapukur Rd',
#         'lat': 22.53309675113572,
#         'lng': 88.34708213260403,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53309675113572,
#           'lng': 88.34708213260403}],
#         'distance': 1045,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['2, Paddapukur Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfe4',
#          'name': 'Indian Sweet Shop',
#          'pluralName': 'Indian Sweet Shops',
#          'shortName': 'Indian Sweets',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd7482a7716469f62fb4560-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f179ce1e4b035bfa73f9f27',
#        'name': 'Princep Ghat',
#        'location': {'address': 'Strand Rd',
#         'lat': 22.559267458018144,
#         'lng': 88.33305706140452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.559267458018144,
#           'lng': 88.33305706140452}],
#         'distance': 2763,
#         'postalCode': '700072',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Strand Rd',
#          'Kolkata 700072',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'shortName': 'Harbor / Marina',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f179ce1e4b035bfa73f9f27-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c110a3a81e976b0291410eb',
#        'name': 'Shiraz Golden Restaurant',
#        'location': {'address': '135, Park St',
#         'lat': 22.546535533549203,
#         'lng': 88.3616544965681,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.546535533549203,
#           'lng': 88.3616544965681}],
#         'distance': 1164,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['135, Park St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff4',
#          'name': 'Mughlai Restaurant',
#          'pluralName': 'Mughlai Restaurants',
#          'shortName': 'Mughlai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c110a3a81e976b0291410eb-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56554d95498e0031a81217a2',
#        'name': 'Sienna Store & Cafe',
#        'location': {'address': 'Hindustan Pk',
#         'lat': 22.517641332811532,
#         'lng': 88.3629834651947,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.517641332811532,
#           'lng': 88.3629834651947}],
#         'distance': 2889,
#         'postalCode': '700029',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Hindustan Pk',
#          'Kolkata 700029',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d127951735',
#          'name': 'Arts & Crafts Store',
#          'pluralName': 'Arts & Crafts Stores',
#          'shortName': 'Arts & Crafts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56554d95498e0031a81217a2-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5548d780498e5cef9ae2dcae',
#        'name': '8th Day Cafe & Bakery',
#        'location': {'address': '6, Acharya Jagadish Chandra Bose Rd',
#         'lat': 22.54240650553313,
#         'lng': 88.36098124876465,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.54240650553313,
#           'lng': 88.36098124876465}],
#         'distance': 954,
#         'postalCode': '700015',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['6, Acharya Jagadish Chandra Bose Rd',
#          'Kolkata 700015',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5548d780498e5cef9ae2dcae-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf3b6667e93f04dd8a15969',
#        'name': 'Marco Polo',
#        'location': {'address': '24, Park St',
#         'lat': 22.55147694425327,
#         'lng': 88.35382711655352,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.55147694425327,
#           'lng': 88.35382711655352}],
#         'distance': 1137,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['24, Park St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf3b6667e93f04dd8a15969-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd1a0bd5e0cce72d3bda184',
#        'name': 'Lalit Great Eastern Hotel',
#        'location': {'address': 'Hemanta Basu Sarani',
#         'lat': 22.56796710486943,
#         'lng': 88.35001000801633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.56796710486943,
#           'lng': 88.35001000801633}],
#         'distance': 2958,
#         'postalCode': '700001',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Hemanta Basu Sarani',
#          'Kolkata 700001',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd1a0bd5e0cce72d3bda184-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '534fda8b498e30c1f4f3ccff',
#        'name': 'Serafina',
#        'location': {'address': 'Quest Mall',
#         'lat': 22.539176012738004,
#         'lng': 88.3654510974884,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539176012738004,
#           'lng': 88.3654510974884}],
#         'distance': 1429,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Quest Mall',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-534fda8b498e30c1f4f3ccff-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfa2b8aae60f95f8225b9c9',
#        'name': 'Big Boss',
#        'location': {'address': '54C, Matheswartala Rd',
#         'lat': 22.546493181530703,
#         'lng': 88.3881620914969,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.546493181530703,
#           'lng': 88.3881620914969}],
#         'distance': 3784,
#         'postalCode': '700046',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['54C, Matheswartala Rd',
#          'Kolkata 700046',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfa2b8aae60f95f8225b9c9-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc788f793bdeee1917d37ae',
#        'name': 'Hotel Hindusthan International',
#        'location': {'address': '235/1, Acharya Jagadish Chandra Bose Rd',
#         'lat': 22.541075138603233,
#         'lng': 88.35048995950599,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.541075138603233,
#           'lng': 88.35048995950599}],
#         'distance': 136,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['235/1, Acharya Jagadish Chandra Bose Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc788f793bdeee1917d37ae-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d19f40dbb488cfa6628c1d4',
#        'name': 'Beijing Restaurant',
#        'location': {'address': '77/1, Christopher Rd',
#         'lat': 22.54651846470317,
#         'lng': 88.387213364055,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.54651846470317,
#           'lng': 88.387213364055}],
#         'distance': 3688,
#         'postalCode': '700046',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['77/1, Christopher Rd',
#          'Kolkata 700046',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d19f40dbb488cfa6628c1d4-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdea62ef8cdb1f7a35e8c12',
#        'name': 'Golden Joy',
#        'location': {'address': '50/1, Matherswartala Rd',
#         'lat': 22.545592321408858,
#         'lng': 88.3874745703988,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.545592321408858,
#           'lng': 88.3874745703988}],
#         'distance': 3700,
#         'postalCode': '700046',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['50/1, Matherswartala Rd',
#          'Kolkata 700046',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
# ...
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bee95bfe24d20a1960e7314-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52b5ad08498ef44082677bf3',
#        'name': 'Wow! Momo',
#        'location': {'address': 'City Centre Mall',
#         'lat': 22.587970893198296,
#         'lng': 88.4080982208252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.587970893198296,
#           'lng': 88.4080982208252}],
#         'distance': 7769,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['City Centre Mall',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d108941735',
#          'name': 'Dumpling Restaurant',
#          'pluralName': 'Dumpling Restaurants',
#          'shortName': 'Dumplings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52b5ad08498ef44082677bf3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a6f8a6498ed2ccd38fe001',
#        'name': 'Balaram Mullick & Radharaman Mullick',
#        'location': {'address': '1625, Rajdanga Main Rd',
#         'lat': 22.513985788455038,
#         'lng': 88.39743811965602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.513985788455038,
#           'lng': 88.39743811965602}],
#         'distance': 5603,
#         'postalCode': '700107',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['1625, Rajdanga Main Rd',
#          'Kolkata 700107',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfe4',
#          'name': 'Indian Sweet Shop',
#          'pluralName': 'Indian Sweet Shops',
#          'shortName': 'Indian Sweets',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51a6f8a6498ed2ccd38fe001-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50d47434e4b02586abeeff15',
#        'name': 'The Gateway Hotel By Taj',
#        'location': {'address': '1930, Rajdanga Main Rd',
#         'lat': 22.51293358111395,
#         'lng': 88.40080261230469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.51293358111395,
#           'lng': 88.40080261230469}],
#         'distance': 5958,
#         'postalCode': '700107',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['1930, Rajdanga Main Rd',
#          'Kolkata 700107',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50d47434e4b02586abeeff15-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca2a6b3f832a1cd9b2e97e5',
#        'name': 'Waterside Cafe',
#        'location': {'address': 'Hyatt Regency',
#         'lat': 22.570363182688432,
#         'lng': 88.40535279113438,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.570363182688432,
#           'lng': 88.40535279113438}],
#         'distance': 6381,
#         'postalCode': '700098',
#         'cc': 'IN',
#         'neighborhood': 'Salt Lake City',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Hyatt Regency',
#          'Kolkata 700098',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca2a6b3f832a1cd9b2e97e5-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce21a88f8a4a1438eb7eebc',
#        'name': 'Acharya Jagadish Chandra Bose Indian Botanic Garden',
#        'location': {'address': 'Shibpur',
#         'lat': 22.558180822938677,
#         'lng': 88.28922271728514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.558180822938677,
#           'lng': 88.28922271728514}],
#         'distance': 6694,
#         'postalCode': '711103',
#         'cc': 'IN',
#         'city': 'Hāora',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Shibpur',
#          'Hāora 711103',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a22',
#          'name': 'Botanical Garden',
#          'pluralName': 'Botanical Gardens',
#          'shortName': 'Botanical Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/botanicalgarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce21a88f8a4a1438eb7eebc-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d81bd59ebb4236a6f764558',
#        'name': 'Charnock City',
#        'location': {'address': 'KB-26 Broadway  Salt Lake City',
#         'lat': 22.567351538075286,
#         'lng': 88.41120493536599,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.567351538075286,
#           'lng': 88.41120493536599}],
#         'distance': 6757,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['KB-26 Broadway  Salt Lake City',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d81bd59ebb4236a6f764558-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50d443eee4b098fb28cc81ca',
#        'name': 'Momo I Am',
#        'location': {'address': '195C, Jodhpur Gardens',
#         'lat': 22.50305005004157,
#         'lng': 88.35818376681533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.50305005004157,
#           'lng': 88.35818376681533}],
#         'distance': 4324,
#         'postalCode': '700045',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['195C, Jodhpur Gardens',
#          'Kolkata 700045',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d108941735',
#          'name': 'Dumpling Restaurant',
#          'pluralName': 'Dumpling Restaurants',
#          'shortName': 'Dumplings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50d443eee4b098fb28cc81ca-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8b02cc02d540e452a85f81',
#        'name': 'Crossword Bookstores Ltd',
#        'location': {'address': '320A, Block A, DC Block, Sector 1, Salt Lake',
#         'lat': 22.58764400020678,
#         'lng': 88.40836644172668,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.58764400020678,
#           'lng': 88.40836644172668}],
#         'distance': 7766,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['320A, Block A, DC Block, Sector 1, Salt Lake',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8b02cc02d540e452a85f81-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d443e6b0349224b37f4f74e',
#        'name': 'Barbecue Nation',
#        'location': {'address': 'RDB Boulevard, Sector V',
#         'lat': 22.568643250569668,
#         'lng': 88.43313932418823,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.568643250569668,
#           'lng': 88.43313932418823}],
#         'distance': 8897,
#         'postalCode': '700091',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['RDB Boulevard, Sector V',
#          'Kolkata 700091',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d443e6b0349224b37f4f74e-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d50075b9ffc236a77eb14a7',
#        'name': 'Bon Appetit Cafe',
#        'location': {'address': 'AD 34, Sector 1, Salt Lake',
#         'lat': 22.59568301675862,
#         'lng': 88.406850770348,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.59568301675862,
#           'lng': 88.406850770348}],
#         'distance': 8278,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['AD 34, Sector 1, Salt Lake',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d50075b9ffc236a77eb14a7-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e76b2711d29c9d5716c206',
#        'name': '6 Ballygunge Place',
#        'location': {'address': 'DD 31A, Sector 1, Salt Lake',
#         'lat': 22.590298708111384,
#         'lng': 88.40925335653736,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.590298708111384,
#           'lng': 88.40925335653736}],
#         'distance': 8031,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['DD 31A, Sector 1, Salt Lake',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff5',
#          'name': 'Bengali Restaurant',
#          'pluralName': 'Bengali Restaurants',
#          'shortName': 'Bengali',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e76b2711d29c9d5716c206-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce160d9df986ea8c649ec16',
#        'name': 'Stadel',
#        'location': {'address': 'Gate No. 3, Salt Lake Stadium',
#         'lat': 22.569257497215474,
#         'lng': 88.41127395629883,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.569257497215474,
#           'lng': 88.41127395629883}],
#         'distance': 6857,
#         'postalCode': '700091',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Gate No. 3, Salt Lake Stadium',
#          'Kolkata 700091',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce160d9df986ea8c649ec16-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ff9afcae4b0d48ad3d1766f',
#        'name': 'The Darjeeling',
#        'location': {'address': 'DD 28, Gorkha Bhawan, Sector 1, Salt Lake',
#         'lat': 22.5887336404945,
#         'lng': 88.40947151184082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.5887336404945,
#           'lng': 88.40947151184082}],
#         'distance': 7931,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['DD 28, Gorkha Bhawan, Sector 1, Salt Lake',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '52af39fb3cf9994f4e043be9',
#          'name': 'Tibetan Restaurant',
#          'pluralName': 'Tibetan Restaurants',
#          'shortName': 'Tibetan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tibetan_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ff9afcae4b0d48ad3d1766f-99'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
filtered_columns = ['venue.name', 'venue.id', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues
# Out:
#                                            venue.name  \
# 0                                      The Blue Poppy
# 1                                      Jai Hind Dhaba
# 2                                   Victoria Memorial
# 3                        Balwant Singh's Eating House
# 4                                           Peter Cat
# 5                                        Oh! Calcutta
# 6                                            Yauatcha
# 7                                              Maidan
# 8                                    The Oberoi Grand
# 9                                            Nocturne
# 10                                         Taj Bengal
# 11                                          The Rouge
# 12                                        TGI Fridays
# 13                                      Blue & Beyond
# 14                                        Underground
# 15                                        Eden Garden
# 16                                             Mithai
# 17                                             Flurys
# 18                                         Quest Mall
# 19                                         Monkey Bar
# 20                                 6 Ballygunge Place
# 21                                    The French Loaf
# 22                                            Bar-B-Q
# 23                                   Bombay Brasserie
# 24                                            Mocambo
# 25                                          Sonargaon
# 26                                               Aqua
# 27                                            Arsalan
# 28               Balaram Mullick & Radharaman Mullick
# 29                                       Princep Ghat
# 30                           Shiraz Golden Restaurant
# 31                                Sienna Store & Cafe
# 32                              8th Day Cafe & Bakery
# 33                                         Marco Polo
# 34                          Lalit Great Eastern Hotel
# 35                                           Serafina
# 36                                           Big Boss
# 37                     Hotel Hindusthan International
# 38                                 Beijing Restaurant
# 39                                         Golden Joy
# 40                                   Oxford Bookstore
# 41                                       The Junction
# 42                                               Inox
# 43                                     Acropolis Mall
# 44                                          ITC Sonar
# 45                                    The Irish House
# 46                         India Restaurant & Caterer
# 47                                    Triangular Park
# 48                                         Paris Café
# 49                                             Subway
# 50                                           Starmark
# 51                                        Go Lebanese
# 52                                           Fabindia
# 53                                Chili's Grill & Bar
# 54                                            Arsalan
# 55                                    Deshapriya Park
# 56                                             Olypub
# 57                                    South City Mall
# 58                 Calcutta Cricket and Football Club
# 59                                            Chowman
# 60                              Hyatt Regency Kolkata
# 61                                               INOX
# 62                    Royal Calcutta Golf Club (RCGC)
# 63                                    Tollygunge Club
# 64                                  Gariahat Junction
# 65                                              Amber
# 66           Girish Chandra Dey & Nakur Chandra Nandy
# 67                                         Kookie Jar
# 68                                           The GRID
# 69                                    Cafe Coffee Day
# 70                                     Mainland China
# 71                                    Spencer's Hyper
# 72                                  JW Marriott Hotel
# 73                                         Haji Saheb
# 74                                         JW Kitchen
# 75                                       Science City
# 76                                            Barista
# 77                                      Shoppers Stop
# 78                                     Punjabee Rasoi
# 79                                          Cinépolis
# 80                                          La Cucina
# 81                                         Pantaloons
# 82                                          Starbucks
# 83                                    Denzong Kitchen
# 84                                    Cafe Coffee Day
# 85                                              Opium
# 86                                        City Centre
# 87                                          Wow! Momo
# 88               Balaram Mullick & Radharaman Mullick
# 89                           The Gateway Hotel By Taj
# 90                                     Waterside Cafe
# 91  Acharya Jagadish Chandra Bose Indian Botanic G...
# 92                                      Charnock City
# 93                                          Momo I Am
# 94                           Crossword Bookstores Ltd
# 95                                    Barbecue Nation
# 96                                   Bon Appetit Cafe
# 97                                 6 Ballygunge Place
# 98                                             Stadel
# 99                                     The Darjeeling
#
#                     venue.id                venue.categories  \
# 0   4d43fd7b4e5d370413f4e593                Asian Restaurant
# 1   4d050f03347da1cd0d012f8f                           Dhaba
# 2   4c0218258ef2c9b66d9c16fc                  History Museum
# 3   4d1c6d5a7e10a35dcb13ff82                           Dhaba
# 4   4c284edefe6e2d7f5417533c               Indian Restaurant
# 5   4c0a0ee8bbc676b0b24449d5              Bengali Restaurant
# 6   534fda5e498e8696570687b8              Chinese Restaurant
# 7   50ee506ee4b0f01d13d51008                           Field
# 8   4d4c107ee1ec6dcbad95d475                           Hotel
# 9   4d70225a9aac224bd12337ed                       Nightclub
# 10  4bd1cf255e0cce72fd05a284                           Hotel
# 11  5001966ae4b0444ec20e4135                            Café
# 12  55e44fc0498e6b62fb94d77b             American Restaurant
# 13  4e2c0d7a18a80bb0585fae4d                             Pub
# 14  4beffa4ca09076b01ea229d4                       Nightclub
# 15  4bc9c62b511f9521982faec7                  Cricket Ground
# 16  511b63ace4b00262d57ed073               Indian Sweet Shop
# 17  4befc8c03a002d7f386285a4                          Bakery
# 18  5274b7f111d2b513631071a5                   Shopping Mall
# 19  57c9d100498e12bbb73fa6a4                       Gastropub
# 20  4d54ed50c6edf04d1af5bea2              Bengali Restaurant
# 21  4cf3afe36c29236adc2472a2                          Bakery
# 22  4e0b1e8422713e13018ee0a1                       BBQ Joint
# 23  534a4e4f498e504051fbb385               Indian Restaurant
# 24  4beebe513686c9b69bde246e                      Restaurant
# 25  4da1df087aee548112fec9fe               Indian Restaurant
# 26  4bbf785db083a593d77fa3e9                          Lounge
# 27  5239ee910493e46a092f23c7              Mughlai Restaurant
# 28  4fd7482a7716469f62fb4560               Indian Sweet Shop
# 29  4f179ce1e4b035bfa73f9f27                 Harbor / Marina
# 30  4c110a3a81e976b0291410eb              Mughlai Restaurant
# 31  56554d95498e0031a81217a2             Arts & Crafts Store
# 32  5548d780498e5cef9ae2dcae                            Café
# 33  4cf3b6667e93f04dd8a15969              Chinese Restaurant
# 34  4bd1a0bd5e0cce72d3bda184                           Hotel
# 35  534fda8b498e30c1f4f3ccff              Italian Restaurant
# 36  4dfa2b8aae60f95f8225b9c9              Chinese Restaurant
# 37  4bc788f793bdeee1917d37ae                           Hotel
# 38  4d19f40dbb488cfa6628c1d4              Chinese Restaurant
# 39  4cdea62ef8cdb1f7a35e8c12              Chinese Restaurant
# 40  4d201719d7b0b1f76417129f                       Bookstore
# 41  4c59af3e04f9be9a23ecef60                          Lounge
# 42  528c3b2611d2e42e49b72774                       Multiplex
# 43  56042ace498efedb770e3dcc                   Shopping Mall
# 44  4bb4f2d60fb7b7132cb9bf8a                           Hotel
# 45  534fd97c498effb74edc096b                       Irish Pub
# 46  5234b18e04932a88f1ff430d               Awadhi Restaurant
# 47  4fc0f8ade4b0d51624e249a9                            Park
# 48  514d613de4b0ab03fe0601fb                          Bakery
# 49  4d145ea085fc6dcbe22e974e                  Sandwich Place
# 50  4cd2887a158c54818d68afe4                       Bookstore
# 51  51409ae6e4b0c2b51cfd04b0              Falafel Restaurant
# 52  4edb473d5c5c96a2ff551b70                        Boutique
# 53  52b5503411d2be7ddd7aaa58              Tex-Mex Restaurant
# 54  4d3026dfa241f04d2878b127              Mughlai Restaurant
# 55  4ce40d96dc85a1432f6b49d2                            Park
# 56  4d7c82a186cfa1439d8ccba0                             Pub
# 57  4bb3427e715eef3bdd1286bb                   Shopping Mall
# 58  4c526d619426c9287fa95e75                     Sports Club
# 59  51bc401a498e587913694c22              Chinese Restaurant
# 60  4bc788f893bdeee1927d37ae                           Hotel
# 61  4d4404083616b60c94b5dfc2                       Multiplex
# 62  4bee191a946c0f47727fa363                     Golf Course
# 63  4cc82963be874688d1ad82af                     Sports Club
# 64  4fd607c3121dc5ba008f840a                           Plaza
# 65  4dada0736e81d745d7456d26               Indian Restaurant
# 66  5085d451e4b0fedcb352298c               Indian Sweet Shop
# 67  4e186f9b14957dc705d6fbf8                            Café
# 68  579747adcd1069eeb483cc39                         Brewery
# 69  533ada3d498e2b453cfdcb32                            Café
# 70  4c0651d9761ac9b60ab92074              Chinese Restaurant
# 71  4d3406408250f04d37e501e1                Department Store
# 72  581963bcb1488442b4946d11                           Hotel
# 73  4ecfb84661af476c07b61cd0              Mughlai Restaurant
# 74  58627d2de309e102989bd82f  Multicuisine Indian Restaurant
# 75  4cc41d7e914137048293c055                      Theme Park
# 76  4d7498eb9d2fa1432ab6f3d6                            Café
# 77  4cd291d190f23704107e8be8                  Clothing Store
# 78  50b22e9ce4b06cad40a4efff                           Dhaba
# 79  56042b21498e21a5e19ae496                       Multiplex
# 80  4ba25edaf964a52033f237e3              Italian Restaurant
# 81  4cd28d81773ba143cb7bbbe3                  Clothing Store
# 82  565d6443498ed226cf90e9a2                     Coffee Shop
# 83  512dcdb7e4b0255d5e6b4779             Dumpling Restaurant
# 84  4dd4064bd1643acaa1eea78a                            Café
# 85  4dbbf09743a1d8504b7cfac8                             Bar
# 86  4bee95bfe24d20a1960e7314                   Shopping Mall
# 87  52b5ad08498ef44082677bf3             Dumpling Restaurant
# 88  51a6f8a6498ed2ccd38fe001               Indian Sweet Shop
# 89  50d47434e4b02586abeeff15                           Hotel
# 90  4ca2a6b3f832a1cd9b2e97e5                            Café
# 91  4ce21a88f8a4a1438eb7eebc                Botanical Garden
# 92  4d81bd59ebb4236a6f764558               Indian Restaurant
# 93  50d443eee4b098fb28cc81ca             Dumpling Restaurant
# 94  4e8b02cc02d540e452a85f81                       Bookstore
# 95  4d443e6b0349224b37f4f74e               Indian Restaurant
# 96  4d50075b9ffc236a77eb14a7                            Café
# 97  52e76b2711d29c9d5716c206              Bengali Restaurant
# 98  4ce160d9df986ea8c649ec16                           Diner
# 99  4ff9afcae4b0d48ad3d1766f              Tibetan Restaurant
#
#     venue.location.lat  venue.location.lng
# 0            22.548543           88.351353
# 1            22.533109           88.353268
# 2            22.545844           88.342890
# 3            22.537714           88.344220
# 4            22.552365           88.352544
# 5            22.538357           88.351406
# 6            22.539091           88.365573
# 7            22.549906           88.344219
# 8            22.561749           88.351594
# 9            22.545078           88.357384
# 10           22.537459           88.334066
# 11           22.541217           88.359267
# 12           22.538592           88.351398
# 13           22.559131           88.353280
# 14           22.541290           88.350629
# 15           22.564542           88.343296
# 16           22.538354           88.364990
# 17           22.552786           88.352625
# 18           22.539068           88.365525
# 19           22.544286           88.351960
# 20           22.527712           88.368677
# 21           22.539240           88.354921
# 22           22.553125           88.352625
# 23           22.538770           88.365532
# 24           22.553206           88.353296
# 25           22.537545           88.334210
# 26           22.554734           88.352180
# 27           22.553897           88.354063
# 28           22.533097           88.347082
# 29           22.559267           88.333057
# 30           22.546536           88.361654
# 31           22.517641           88.362983
# 32           22.542407           88.360981
# 33           22.551477           88.353827
# 34           22.567967           88.350010
# 35           22.539176           88.365451
# 36           22.546493           88.388162
# 37           22.541075           88.350490
# 38           22.546518           88.387213
# 39           22.545592           88.387475
# 40           22.553652           88.351732
# 41           22.537845           88.334475
# 42           22.539139           88.365559
# 43           22.514823           88.393235
# 44           22.544284           88.398017
# 45           22.539018           88.365570
# 46           22.538904           88.322278
# 47           22.517924           88.358289
# 48           22.534915           88.364812
# 49           22.501667           88.361787
# 50           22.501605           88.361726
# 51           22.513831           88.353231
# 52           22.518523           88.363466
# 53           22.539151           88.365496
# 54           22.543709           88.365994
# 55           22.518395           88.353177
# 56           22.553551           88.351925
# 57           22.501758           88.361726
# 58           22.532940           88.364233
# 59           22.526977           88.368509
# 60           22.570358           88.405319
# 61           22.570893           88.401026
# 62           22.494600           88.351066
# 63           22.495360           88.343084
# 64           22.519704           88.365422
# 65           22.567544           88.351847
# 66           22.596040           88.367485
# 67           22.522208           88.331249
# 68           22.541975           88.386362
# 69           22.577619           88.390439
# 70           22.501652           88.361699
# 71           22.501436           88.361664
# 72           22.547920           88.399348
# 73           22.499910           88.317289
# 74           22.547905           88.399354
# 75           22.541507           88.396301
# 76           22.514853           88.352595
# 77           22.501683           88.361759
# 78           22.515974           88.392545
# 79           22.514824           88.393236
# 80           22.570970           88.405358
# 81           22.501725           88.361766
# 82           22.501476           88.361814
# 83           22.486825           88.361363
# 84           22.515525           88.354363
# 85           22.568473           88.434431
# 86           22.587921           88.408098
# 87           22.587971           88.408098
# 88           22.513986           88.397438
# 89           22.512934           88.400803
# 90           22.570363           88.405353
# 91           22.558181           88.289223
# 92           22.567352           88.411205
# 93           22.503050           88.358184
# 94           22.587644           88.408366
# 95           22.568643           88.433139
# 96           22.595683           88.406851
# 97           22.590299           88.409253
# 98           22.569257           88.411274
# 99           22.588734           88.409472

# %%
#fix the column names so they look relatively normal

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                            name                        id         categories  \
# 0                The Blue Poppy  4d43fd7b4e5d370413f4e593   Asian Restaurant
# 1                Jai Hind Dhaba  4d050f03347da1cd0d012f8f              Dhaba
# 2             Victoria Memorial  4c0218258ef2c9b66d9c16fc     History Museum
# 3  Balwant Singh's Eating House  4d1c6d5a7e10a35dcb13ff82              Dhaba
# 4                     Peter Cat  4c284edefe6e2d7f5417533c  Indian Restaurant
#
#          lat        lng
# 0  22.548543  88.351353
# 1  22.533109  88.353268
# 2  22.545844  88.342890
# 3  22.537714  88.344220
# 4  22.552365  88.352544

# %%
nearby_venues.shape
# Out:
# (100, 5)

# %% [markdown]
# ### DATA MANIPULATION

# %% [markdown]
# Some of the venues contained business that one would not go to, if on a tight schedule. So i filtered out those venues using list **not_needed**.<br> The rest will be split into food venues and other venues. The food venues will be clustered using k means while others will be superimposed on the map.

# %%
not_needed=['Field','Cricket Ground','Arts & Crafts Store','Bookstore','Boutique','Sports Club','Golf Course','Department Store','Hotel']
filtered_venues=nearby_venues[~nearby_venues['categories'].isin(not_needed)]
others=['History Museum','Shopping Mall','Park','Harbor / Marina','Multiplex','Theme Park','Clothing Store','Botanical Garden']
food_venues=filtered_venues[~nearby_venues['categories'].isin(others)]
print('food_venues='+str(food_venues.shape))
other_venues=filtered_venues[nearby_venues['categories'].isin(others)]
print('other_venues='+str(other_venues.shape))
# Out:
# food_venues=(66, 5)
# other_venues=(15, 5)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# The Top_Locations dataframe and other_venues had 2 locations in common -- Victoria Memorial Hall and Science City.<br>
# Inorder to avoid duplicity, these locations will  be removed.

# %%
other_venues.reset_index(inplace=True)
other_venues.drop([0 ,9],axis=0,inplace=True)
other_venues.drop("index",axis=1,inplace=True)
other_venues
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                                                  name  \
# 1                                          Quest Mall
# 2                                        Princep Ghat
# 3                                                Inox
# 4                                      Acropolis Mall
# 5                                     Triangular Park
# 6                                     Deshapriya Park
# 7                                     South City Mall
# 8                                                INOX
# 10                                      Shoppers Stop
# 11                                          Cinépolis
# 12                                         Pantaloons
# 13                                        City Centre
# 14  Acharya Jagadish Chandra Bose Indian Botanic G...
#
#                           id        categories        lat        lng
# 1   5274b7f111d2b513631071a5     Shopping Mall  22.539068  88.365525
# 2   4f179ce1e4b035bfa73f9f27   Harbor / Marina  22.559267  88.333057
# 3   528c3b2611d2e42e49b72774         Multiplex  22.539139  88.365559
# 4   56042ace498efedb770e3dcc     Shopping Mall  22.514823  88.393235
# 5   4fc0f8ade4b0d51624e249a9              Park  22.517924  88.358289
# 6   4ce40d96dc85a1432f6b49d2              Park  22.518395  88.353177
# 7   4bb3427e715eef3bdd1286bb     Shopping Mall  22.501758  88.361726
# 8   4d4404083616b60c94b5dfc2         Multiplex  22.570893  88.401026
# 10  4cd291d190f23704107e8be8    Clothing Store  22.501683  88.361759
# 11  56042b21498e21a5e19ae496         Multiplex  22.514824  88.393236
# 12  4cd28d81773ba143cb7bbbe3    Clothing Store  22.501725  88.361766
# 13  4bee95bfe24d20a1960e7314     Shopping Mall  22.587921  88.408098
# 14  4ce21a88f8a4a1438eb7eebc  Botanical Garden  22.558181  88.289223

# %%
venue_id_list = food_venues['id'].tolist()
venue_id_list
# Out:
# ['4d43fd7b4e5d370413f4e593',
#  '4d050f03347da1cd0d012f8f',
#  '4d1c6d5a7e10a35dcb13ff82',
#  '4c284edefe6e2d7f5417533c',
#  '4c0a0ee8bbc676b0b24449d5',
#  '534fda5e498e8696570687b8',
#  '4d70225a9aac224bd12337ed',
#  '5001966ae4b0444ec20e4135',
#  '55e44fc0498e6b62fb94d77b',
#  '4e2c0d7a18a80bb0585fae4d',
#  '4beffa4ca09076b01ea229d4',
#  '511b63ace4b00262d57ed073',
#  '4befc8c03a002d7f386285a4',
#  '57c9d100498e12bbb73fa6a4',
#  '4d54ed50c6edf04d1af5bea2',
#  '4cf3afe36c29236adc2472a2',
#  '4e0b1e8422713e13018ee0a1',
#  '534a4e4f498e504051fbb385',
#  '4beebe513686c9b69bde246e',
#  '4da1df087aee548112fec9fe',
#  '4bbf785db083a593d77fa3e9',
#  '5239ee910493e46a092f23c7',
#  '4fd7482a7716469f62fb4560',
#  '4c110a3a81e976b0291410eb',
#  '5548d780498e5cef9ae2dcae',
#  '4cf3b6667e93f04dd8a15969',
#  '534fda8b498e30c1f4f3ccff',
#  '4dfa2b8aae60f95f8225b9c9',
#  '4d19f40dbb488cfa6628c1d4',
#  '4cdea62ef8cdb1f7a35e8c12',
#  '4c59af3e04f9be9a23ecef60',
#  '534fd97c498effb74edc096b',
#  '5234b18e04932a88f1ff430d',
#  '514d613de4b0ab03fe0601fb',
#  '4d145ea085fc6dcbe22e974e',
#  '51409ae6e4b0c2b51cfd04b0',
#  '52b5503411d2be7ddd7aaa58',
#  '4d3026dfa241f04d2878b127',
#  '4d7c82a186cfa1439d8ccba0',
#  '51bc401a498e587913694c22',
#  '4fd607c3121dc5ba008f840a',
#  '4dada0736e81d745d7456d26',
#  '5085d451e4b0fedcb352298c',
#  '4e186f9b14957dc705d6fbf8',
#  '579747adcd1069eeb483cc39',
#  '533ada3d498e2b453cfdcb32',
#  '4c0651d9761ac9b60ab92074',
#  '4ecfb84661af476c07b61cd0',
#  '58627d2de309e102989bd82f',
#  '4d7498eb9d2fa1432ab6f3d6',
#  '50b22e9ce4b06cad40a4efff',
#  '4ba25edaf964a52033f237e3',
#  '565d6443498ed226cf90e9a2',
#  '512dcdb7e4b0255d5e6b4779',
#  '4dd4064bd1643acaa1eea78a',
#  '4dbbf09743a1d8504b7cfac8',
#  '52b5ad08498ef44082677bf3',
#  '51a6f8a6498ed2ccd38fe001',
#  '4ca2a6b3f832a1cd9b2e97e5',
#  '4d81bd59ebb4236a6f764558',
#  '50d443eee4b098fb28cc81ca',
#  '4d443e6b0349224b37f4f74e',
#  '4d50075b9ffc236a77eb14a7',
#  '52e76b2711d29c9d5716c206',
#  '4ce160d9df986ea8c649ec16',
#  '4ff9afcae4b0d48ad3d1766f']

# %% [markdown]
# The next step is to get the amount of likes each venue got. I used Foursquare API to get those data.

# %%
#set up to pull the likes from the API based on venue ID
url_list = []
like_list = []
json_list = []

for i in venue_id_list:
    venue_url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(i, CLIENT_ID, CLIENT_SECRET, VERSION)
    url_list.append(venue_url)
for link in url_list:
    result = requests.get(link).json()
    likes = result['response']['likes']['count']
    like_list.append(likes)
print(like_list)
# Out:
# [23, 48, 74, 175, 20, 14, 36, 7, 10, 12, 21, 7, 151, 9, 39, 8, 100, 7, 80, 8, 24, 13, 7, 21, 10, 12, 6, 22, 20, 20, 8, 22, 10, 9, 14, 15, 40, 35, 54, 6, 20, 8, 13, 8, 13, 14, 41, 10, 11, 11, 5, 9, 1, 5, 5, 21, 5, 5, 16, 7, 5, 40, 16, 8, 14, 11]

# %%
print(len(like_list))
print(len(venue_id_list))
# Out:
# 66
# 66

# %%
#the list was added to the dataframe
food_venues['Likes']=like_list
food_venues.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                            name                        id          categories  \
# 0                The Blue Poppy  4d43fd7b4e5d370413f4e593    Asian Restaurant
# 1                Jai Hind Dhaba  4d050f03347da1cd0d012f8f               Dhaba
# 3  Balwant Singh's Eating House  4d1c6d5a7e10a35dcb13ff82               Dhaba
# 4                     Peter Cat  4c284edefe6e2d7f5417533c   Indian Restaurant
# 5                  Oh! Calcutta  4c0a0ee8bbc676b0b24449d5  Bengali Restaurant
#
#          lat        lng  Likes
# 0  22.548543  88.351353     23
# 1  22.533109  88.353268     48
# 3  22.537714  88.344220     74
# 4  22.552365  88.352544    175
# 5  22.538357  88.351406     20

# %%
#statistical properties of the likes column was found out to fix the quality boundaries
food_venues['Likes'].describe()
# Out:
# count     66.000000
# mean      23.318182
# std       31.065271
# min        1.000000
# 25%        8.000000
# 50%       13.000000
# 75%       21.750000
# max      175.000000
# Name: Likes, dtype: float64

# %% [markdown]
# From the output above, we can see obtain the 1st, 2nd and 3rd quartiles of the data. These will be defined as our boundaries.
# A custom method will be used to apply our defined quality categories such as poor, below average, above average and excellent

# %%
# let's set up a function that will re-categorize our restaurants based on likes

def conditions(s):
    if s['Likes']<=8:
        return 'poor'
    if s['Likes']<=13:
        return 'below avg'
    if s['Likes']<=21:
        return 'above avg'
    if s['Likes']>21:
        return 'excellent'

food_venues['Quality']=food_venues.apply(conditions, axis=1)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
food_venues
# Out:
#                                         name                        id  \
# 0                             The Blue Poppy  4d43fd7b4e5d370413f4e593
# 1                             Jai Hind Dhaba  4d050f03347da1cd0d012f8f
# 3               Balwant Singh's Eating House  4d1c6d5a7e10a35dcb13ff82
# 4                                  Peter Cat  4c284edefe6e2d7f5417533c
# 5                               Oh! Calcutta  4c0a0ee8bbc676b0b24449d5
# 6                                   Yauatcha  534fda5e498e8696570687b8
# 9                                   Nocturne  4d70225a9aac224bd12337ed
# 11                                 The Rouge  5001966ae4b0444ec20e4135
# 12                               TGI Fridays  55e44fc0498e6b62fb94d77b
# 13                             Blue & Beyond  4e2c0d7a18a80bb0585fae4d
# 14                               Underground  4beffa4ca09076b01ea229d4
# 16                                    Mithai  511b63ace4b00262d57ed073
# 17                                    Flurys  4befc8c03a002d7f386285a4
# 19                                Monkey Bar  57c9d100498e12bbb73fa6a4
# 20                        6 Ballygunge Place  4d54ed50c6edf04d1af5bea2
# 21                           The French Loaf  4cf3afe36c29236adc2472a2
# 22                                   Bar-B-Q  4e0b1e8422713e13018ee0a1
# 23                          Bombay Brasserie  534a4e4f498e504051fbb385
# 24                                   Mocambo  4beebe513686c9b69bde246e
# 25                                 Sonargaon  4da1df087aee548112fec9fe
# 26                                      Aqua  4bbf785db083a593d77fa3e9
# 27                                   Arsalan  5239ee910493e46a092f23c7
# 28      Balaram Mullick & Radharaman Mullick  4fd7482a7716469f62fb4560
# 30                  Shiraz Golden Restaurant  4c110a3a81e976b0291410eb
# 32                     8th Day Cafe & Bakery  5548d780498e5cef9ae2dcae
# 33                                Marco Polo  4cf3b6667e93f04dd8a15969
# 35                                  Serafina  534fda8b498e30c1f4f3ccff
# 36                                  Big Boss  4dfa2b8aae60f95f8225b9c9
# 38                        Beijing Restaurant  4d19f40dbb488cfa6628c1d4
# 39                                Golden Joy  4cdea62ef8cdb1f7a35e8c12
# 41                              The Junction  4c59af3e04f9be9a23ecef60
# 45                           The Irish House  534fd97c498effb74edc096b
# 46                India Restaurant & Caterer  5234b18e04932a88f1ff430d
# 48                                Paris Café  514d613de4b0ab03fe0601fb
# 49                                    Subway  4d145ea085fc6dcbe22e974e
# 51                               Go Lebanese  51409ae6e4b0c2b51cfd04b0
# 53                       Chili's Grill & Bar  52b5503411d2be7ddd7aaa58
# 54                                   Arsalan  4d3026dfa241f04d2878b127
# 56                                    Olypub  4d7c82a186cfa1439d8ccba0
# 59                                   Chowman  51bc401a498e587913694c22
# 64                         Gariahat Junction  4fd607c3121dc5ba008f840a
# 65                                     Amber  4dada0736e81d745d7456d26
# 66  Girish Chandra Dey & Nakur Chandra Nandy  5085d451e4b0fedcb352298c
# 67                                Kookie Jar  4e186f9b14957dc705d6fbf8
# 68                                  The GRID  579747adcd1069eeb483cc39
# 69                           Cafe Coffee Day  533ada3d498e2b453cfdcb32
# 70                            Mainland China  4c0651d9761ac9b60ab92074
# 73                                Haji Saheb  4ecfb84661af476c07b61cd0
# 74                                JW Kitchen  58627d2de309e102989bd82f
# 76                                   Barista  4d7498eb9d2fa1432ab6f3d6
# 78                            Punjabee Rasoi  50b22e9ce4b06cad40a4efff
# 80                                 La Cucina  4ba25edaf964a52033f237e3
# 82                                 Starbucks  565d6443498ed226cf90e9a2
# 83                           Denzong Kitchen  512dcdb7e4b0255d5e6b4779
# 84                           Cafe Coffee Day  4dd4064bd1643acaa1eea78a
# 85                                     Opium  4dbbf09743a1d8504b7cfac8
# 87                                 Wow! Momo  52b5ad08498ef44082677bf3
# 88      Balaram Mullick & Radharaman Mullick  51a6f8a6498ed2ccd38fe001
# 90                            Waterside Cafe  4ca2a6b3f832a1cd9b2e97e5
# 92                             Charnock City  4d81bd59ebb4236a6f764558
# 93                                 Momo I Am  50d443eee4b098fb28cc81ca
# 95                           Barbecue Nation  4d443e6b0349224b37f4f74e
# 96                          Bon Appetit Cafe  4d50075b9ffc236a77eb14a7
# 97                        6 Ballygunge Place  52e76b2711d29c9d5716c206
# 98                                    Stadel  4ce160d9df986ea8c649ec16
# 99                            The Darjeeling  4ff9afcae4b0d48ad3d1766f
#
#                         categories        lat        lng  Likes    Quality
# 0                 Asian Restaurant  22.548543  88.351353     23  excellent
# 1                            Dhaba  22.533109  88.353268     48  excellent
# 3                            Dhaba  22.537714  88.344220     74  excellent
# 4                Indian Restaurant  22.552365  88.352544    175  excellent
# 5               Bengali Restaurant  22.538357  88.351406     20  above avg
# 6               Chinese Restaurant  22.539091  88.365573     14  above avg
# 9                        Nightclub  22.545078  88.357384     36  excellent
# 11                            Café  22.541217  88.359267      7       poor
# 12             American Restaurant  22.538592  88.351398     10  below avg
# 13                             Pub  22.559131  88.353280     12  below avg
# 14                       Nightclub  22.541290  88.350629     21  above avg
# 16               Indian Sweet Shop  22.538354  88.364990      7       poor
# 17                          Bakery  22.552786  88.352625    151  excellent
# 19                       Gastropub  22.544286  88.351960      9  below avg
# 20              Bengali Restaurant  22.527712  88.368677     39  excellent
# 21                          Bakery  22.539240  88.354921      8       poor
# 22                       BBQ Joint  22.553125  88.352625    100  excellent
# 23               Indian Restaurant  22.538770  88.365532      7       poor
# 24                      Restaurant  22.553206  88.353296     80  excellent
# 25               Indian Restaurant  22.537545  88.334210      8       poor
# 26                          Lounge  22.554734  88.352180     24  excellent
# 27              Mughlai Restaurant  22.553897  88.354063     13  below avg
# 28               Indian Sweet Shop  22.533097  88.347082      7       poor
# 30              Mughlai Restaurant  22.546536  88.361654     21  above avg
# 32                            Café  22.542407  88.360981     10  below avg
# 33              Chinese Restaurant  22.551477  88.353827     12  below avg
# 35              Italian Restaurant  22.539176  88.365451      6       poor
# 36              Chinese Restaurant  22.546493  88.388162     22  excellent
# 38              Chinese Restaurant  22.546518  88.387213     20  above avg
# 39              Chinese Restaurant  22.545592  88.387475     20  above avg
# 41                          Lounge  22.537845  88.334475      8       poor
# 45                       Irish Pub  22.539018  88.365570     22  excellent
# 46               Awadhi Restaurant  22.538904  88.322278     10  below avg
# 48                          Bakery  22.534915  88.364812      9  below avg
# 49                  Sandwich Place  22.501667  88.361787     14  above avg
# 51              Falafel Restaurant  22.513831  88.353231     15  above avg
# 53              Tex-Mex Restaurant  22.539151  88.365496     40  excellent
# 54              Mughlai Restaurant  22.543709  88.365994     35  excellent
# 56                             Pub  22.553551  88.351925     54  excellent
# 59              Chinese Restaurant  22.526977  88.368509      6       poor
# 64                           Plaza  22.519704  88.365422     20  above avg
# 65               Indian Restaurant  22.567544  88.351847      8       poor
# 66               Indian Sweet Shop  22.596040  88.367485     13  below avg
# 67                            Café  22.522208  88.331249      8       poor
# 68                         Brewery  22.541975  88.386362     13  below avg
# 69                            Café  22.577619  88.390439     14  above avg
# 70              Chinese Restaurant  22.501652  88.361699     41  excellent
# 73              Mughlai Restaurant  22.499910  88.317289     10  below avg
# 74  Multicuisine Indian Restaurant  22.547905  88.399354     11  below avg
# 76                            Café  22.514853  88.352595     11  below avg
# 78                           Dhaba  22.515974  88.392545      5       poor
# 80              Italian Restaurant  22.570970  88.405358      9  below avg
# 82                     Coffee Shop  22.501476  88.361814      1       poor
# 83             Dumpling Restaurant  22.486825  88.361363      5       poor
# 84                            Café  22.515525  88.354363      5       poor
# 85                             Bar  22.568473  88.434431     21  above avg
# 87             Dumpling Restaurant  22.587971  88.408098      5       poor
# 88               Indian Sweet Shop  22.513986  88.397438      5       poor
# 90                            Café  22.570363  88.405353     16  above avg
# 92               Indian Restaurant  22.567352  88.411205      7       poor
# 93             Dumpling Restaurant  22.503050  88.358184      5       poor
# 95               Indian Restaurant  22.568643  88.433139     40  excellent
# 96                            Café  22.595683  88.406851     16  above avg
# 97              Bengali Restaurant  22.590299  88.409253      8       poor
# 98                           Diner  22.569257  88.411274     14  above avg
# 99              Tibetan Restaurant  22.588734  88.409472     11  below avg

# %%
categories=food_venues.categories.unique().tolist()

# %% [markdown]
# The food venies will again be categorised into different cuisines for easy clustering.<br>
# The 4 categories include:
# 1. Indian food
# 2. Other Asian food
# 3. Western food
# 4. Beverages

# %%
# let's create our new categories and create a function to apply those to our existing data

indian_food = ['Dhaba','Diner', 'Indian Restaurant','Coffee Shop','Bengali Restaurant','Multicuisine Indian Restaurant','Indian Sweet Shop', 'Bakery','Restaurant','Plaza', 'Lounge', 'Awadhi Restaurant','Mughlai Restaurant']
asian_other_than_indian_food = ['Asian Restaurant','Chinese Restaurant','Tibetan Restaurant','Dumpling Restaurant']
western_food = ['Café', 'American Restaurant','BBQ Joint','Sandwich Place','Italian Restaurant','Falafel Restaurant', 'Tex-Mex Restaurant', 'Irish Pub']
bars = ['Nightclub','Bar','Pub','Gastropub','Brewery']

def conditions2(s):
    if s['categories'] in indian_food:
        return 'Indian'
    if s['categories'] in asian_other_than_indian_food:
        return 'Other Asian'
    if s['categories'] in western_food:
        return 'Western food'
    if s['categories'] in bars:
        return 'Beverages'
    
food_venues['Food categories']=food_venues.apply(conditions2, axis=1)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
food_venues.head()
# Out:
#                            name                        id          categories  \
# 0                The Blue Poppy  4d43fd7b4e5d370413f4e593    Asian Restaurant
# 1                Jai Hind Dhaba  4d050f03347da1cd0d012f8f               Dhaba
# 3  Balwant Singh's Eating House  4d1c6d5a7e10a35dcb13ff82               Dhaba
# 4                     Peter Cat  4c284edefe6e2d7f5417533c   Indian Restaurant
# 5                  Oh! Calcutta  4c0a0ee8bbc676b0b24449d5  Bengali Restaurant
#
#          lat        lng  Likes    Quality Food categories
# 0  22.548543  88.351353     23  excellent     Other Asian
# 1  22.533109  88.353268     48  excellent          Indian
# 3  22.537714  88.344220     74  excellent          Indian
# 4  22.552365  88.352544    175  excellent          Indian
# 5  22.538357  88.351406     20  above avg          Indian

# %% [markdown]
# One hot encoding will be done to convert the categorical values to numerical values.<br>

# %%
# one hot encoding
food_venues_onehot = pd.get_dummies(food_venues[['Food categories', 'Quality']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
food_venues_onehot['Name'] = food_venues['name'] 

fixed_columns = [food_venues_onehot.columns[-1]] + list(food_venues_onehot.columns[:-1])
food_venues_onehot = food_venues_onehot[fixed_columns]

food_venues_onehot.head()
# Out:
#                            Name  Beverages  Indian  Other Asian  Western food  \
# 0                The Blue Poppy          0       0            1             0
# 1                Jai Hind Dhaba          0       1            0             0
# 3  Balwant Singh's Eating House          0       1            0             0
# 4                     Peter Cat          0       1            0             0
# 5                  Oh! Calcutta          0       1            0             0
#
#    above avg  below avg  excellent  poor
# 0          0          0          1     0
# 1          0          0          1     0
# 3          0          0          1     0
# 4          0          0          1     0
# 5          1          0          0     0

# %% [markdown]
# ### MODELING WITH K-MEANS

# %%
df = food_venues_onehot.drop('Name', axis=1)

k_clusters = 4 # number of clusters was limited to 4 for simplicity 

# run k-means clustering
kmeans = KMeans(n_clusters=k_clusters, random_state=0).fit(df)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([3, 3, 3, 3, 2, 2, 3, 1, 0, 0, 2, 1, 3, 0, 3, 1, 3, 1, 3, 1, 3, 0,
#        1, 2, 0, 0, 1, 3, 2, 2, 1, 3, 0, 0, 2, 2, 3, 3, 3, 1, 2, 1, 0, 1,
#        0, 2, 3, 0, 0, 0, 1, 0, 1, 1, 1, 2, 1, 1, 2, 1, 1, 3, 2, 1, 2, 0],
#       dtype=int32)

# %%
#adding the labels to the data frame
food_venues['Label'] = kmeans.labels_
food_venues.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                            name                        id          categories  \
# 0                The Blue Poppy  4d43fd7b4e5d370413f4e593    Asian Restaurant
# 1                Jai Hind Dhaba  4d050f03347da1cd0d012f8f               Dhaba
# 3  Balwant Singh's Eating House  4d1c6d5a7e10a35dcb13ff82               Dhaba
# 4                     Peter Cat  4c284edefe6e2d7f5417533c   Indian Restaurant
# 5                  Oh! Calcutta  4c0a0ee8bbc676b0b24449d5  Bengali Restaurant
#
#          lat        lng  Likes    Quality Food categories  Label
# 0  22.548543  88.351353     23  excellent     Other Asian      3
# 1  22.533109  88.353268     48  excellent          Indian      3
# 3  22.537714  88.344220     74  excellent          Indian      3
# 4  22.552365  88.352544    175  excellent          Indian      3
# 5  22.538357  88.351406     20  above avg          Indian      2

# %%
# checking out the count in each cluster
food_venues.Label.value_counts()
# Out:
# 1    20
# 3    17
# 0    15
# 2    14
# Name: Label, dtype: int64

# %% [markdown]
# **Checking out the properties of each cluster:**

# %% [markdown]
# **Cluster 0:**<br>
# Venues Categories: Indian and Western foods dominate<br>
# Quality:All of them are **below average**

# %%
cluster0=food_venues.loc[food_venues['Label']==0]
cluster0['Food categories'].value_counts()
# Out:
# Indian          6
# Western food    4
# Beverages       3
# Other Asian     2
# Name: Food categories, dtype: int64

# %%
cluster0
# Out:
#                                         name                        id  \
# 12                               TGI Fridays  55e44fc0498e6b62fb94d77b
# 13                             Blue & Beyond  4e2c0d7a18a80bb0585fae4d
# 19                                Monkey Bar  57c9d100498e12bbb73fa6a4
# 27                                   Arsalan  5239ee910493e46a092f23c7
# 32                     8th Day Cafe & Bakery  5548d780498e5cef9ae2dcae
# 33                                Marco Polo  4cf3b6667e93f04dd8a15969
# 46                India Restaurant & Caterer  5234b18e04932a88f1ff430d
# 48                                Paris Café  514d613de4b0ab03fe0601fb
# 66  Girish Chandra Dey & Nakur Chandra Nandy  5085d451e4b0fedcb352298c
# 68                                  The GRID  579747adcd1069eeb483cc39
# 73                                Haji Saheb  4ecfb84661af476c07b61cd0
# 74                                JW Kitchen  58627d2de309e102989bd82f
# 76                                   Barista  4d7498eb9d2fa1432ab6f3d6
# 80                                 La Cucina  4ba25edaf964a52033f237e3
# 99                            The Darjeeling  4ff9afcae4b0d48ad3d1766f
#
#                         categories        lat        lng  Likes    Quality  \
# 12             American Restaurant  22.538592  88.351398     10  below avg
# 13                             Pub  22.559131  88.353280     12  below avg
# 19                       Gastropub  22.544286  88.351960      9  below avg
# 27              Mughlai Restaurant  22.553897  88.354063     13  below avg
# 32                            Café  22.542407  88.360981     10  below avg
# 33              Chinese Restaurant  22.551477  88.353827     12  below avg
# 46               Awadhi Restaurant  22.538904  88.322278     10  below avg
# 48                          Bakery  22.534915  88.364812      9  below avg
# 66               Indian Sweet Shop  22.596040  88.367485     13  below avg
# 68                         Brewery  22.541975  88.386362     13  below avg
# 73              Mughlai Restaurant  22.499910  88.317289     10  below avg
# 74  Multicuisine Indian Restaurant  22.547905  88.399354     11  below avg
# 76                            Café  22.514853  88.352595     11  below avg
# 80              Italian Restaurant  22.570970  88.405358      9  below avg
# 99              Tibetan Restaurant  22.588734  88.409472     11  below avg
#
#    Food categories  Label
# 12    Western food      0
# 13       Beverages      0
# 19       Beverages      0
# 27          Indian      0
# 32    Western food      0
# 33     Other Asian      0
# 46          Indian      0
# 48          Indian      0
# 66          Indian      0
# 68       Beverages      0
# 73          Indian      0
# 74          Indian      0
# 76    Western food      0
# 80    Western food      0
# 99     Other Asian      0

# %% [markdown]
# **Cluster 1:**<br>
# Venues Categories: Indian foods dominate<br>
# Quality:All of them are **poor**

# %%
cluster1=food_venues.loc[food_venues['Label']==1]
cluster1['Food categories'].value_counts()
# Out:
# Indian          12
# Other Asian      4
# Western food     4
# Name: Food categories, dtype: int64

# %%
cluster1
# Out:
#                                     name                        id  \
# 11                             The Rouge  5001966ae4b0444ec20e4135
# 16                                Mithai  511b63ace4b00262d57ed073
# 21                       The French Loaf  4cf3afe36c29236adc2472a2
# 23                      Bombay Brasserie  534a4e4f498e504051fbb385
# 25                             Sonargaon  4da1df087aee548112fec9fe
# 28  Balaram Mullick & Radharaman Mullick  4fd7482a7716469f62fb4560
# 35                              Serafina  534fda8b498e30c1f4f3ccff
# 41                          The Junction  4c59af3e04f9be9a23ecef60
# 59                               Chowman  51bc401a498e587913694c22
# 65                                 Amber  4dada0736e81d745d7456d26
# 67                            Kookie Jar  4e186f9b14957dc705d6fbf8
# 78                        Punjabee Rasoi  50b22e9ce4b06cad40a4efff
# 82                             Starbucks  565d6443498ed226cf90e9a2
# 83                       Denzong Kitchen  512dcdb7e4b0255d5e6b4779
# 84                       Cafe Coffee Day  4dd4064bd1643acaa1eea78a
# 87                             Wow! Momo  52b5ad08498ef44082677bf3
# 88  Balaram Mullick & Radharaman Mullick  51a6f8a6498ed2ccd38fe001
# 92                         Charnock City  4d81bd59ebb4236a6f764558
# 93                             Momo I Am  50d443eee4b098fb28cc81ca
# 97                    6 Ballygunge Place  52e76b2711d29c9d5716c206
#
#              categories        lat        lng  Likes Quality Food categories  \
# 11                 Café  22.541217  88.359267      7    poor    Western food
# 16    Indian Sweet Shop  22.538354  88.364990      7    poor          Indian
# 21               Bakery  22.539240  88.354921      8    poor          Indian
# 23    Indian Restaurant  22.538770  88.365532      7    poor          Indian
# 25    Indian Restaurant  22.537545  88.334210      8    poor          Indian
# 28    Indian Sweet Shop  22.533097  88.347082      7    poor          Indian
# 35   Italian Restaurant  22.539176  88.365451      6    poor    Western food
# 41               Lounge  22.537845  88.334475      8    poor          Indian
# 59   Chinese Restaurant  22.526977  88.368509      6    poor     Other Asian
# 65    Indian Restaurant  22.567544  88.351847      8    poor          Indian
# 67                 Café  22.522208  88.331249      8    poor    Western food
# 78                Dhaba  22.515974  88.392545      5    poor          Indian
# 82          Coffee Shop  22.501476  88.361814      1    poor          Indian
# 83  Dumpling Restaurant  22.486825  88.361363      5    poor     Other Asian
# 84                 Café  22.515525  88.354363      5    poor    Western food
# 87  Dumpling Restaurant  22.587971  88.408098      5    poor     Other Asian
# 88    Indian Sweet Shop  22.513986  88.397438      5    poor          Indian
# 92    Indian Restaurant  22.567352  88.411205      7    poor          Indian
# 93  Dumpling Restaurant  22.503050  88.358184      5    poor     Other Asian
# 97   Bengali Restaurant  22.590299  88.409253      8    poor          Indian
#
#     Label
# 11      1
# 16      1
# 21      1
# 23      1
# 25      1
# 28      1
# 35      1
# 41      1
# 59      1
# 65      1
# 67      1
# 78      1
# 82      1
# 83      1
# 84      1
# 87      1
# 88      1
# 92      1
# 93      1
# 97      1

# %% [markdown]
# **Cluster 2:**<br>
# Venues Categories: Indian and Western foods dominate<br>
# Quality:All of them are **above average**

# %%
cluster2=food_venues.loc[food_venues['Label']==2]
cluster2['Food categories'].value_counts()
# Out:
# Western food    5
# Indian          4
# Other Asian     3
# Beverages       2
# Name: Food categories, dtype: int64

# %%
cluster2
# Out:
#                         name                        id          categories  \
# 5               Oh! Calcutta  4c0a0ee8bbc676b0b24449d5  Bengali Restaurant
# 6                   Yauatcha  534fda5e498e8696570687b8  Chinese Restaurant
# 14               Underground  4beffa4ca09076b01ea229d4           Nightclub
# 30  Shiraz Golden Restaurant  4c110a3a81e976b0291410eb  Mughlai Restaurant
# 38        Beijing Restaurant  4d19f40dbb488cfa6628c1d4  Chinese Restaurant
# 39                Golden Joy  4cdea62ef8cdb1f7a35e8c12  Chinese Restaurant
# 49                    Subway  4d145ea085fc6dcbe22e974e      Sandwich Place
# 51               Go Lebanese  51409ae6e4b0c2b51cfd04b0  Falafel Restaurant
# 64         Gariahat Junction  4fd607c3121dc5ba008f840a               Plaza
# 69           Cafe Coffee Day  533ada3d498e2b453cfdcb32                Café
# 85                     Opium  4dbbf09743a1d8504b7cfac8                 Bar
# 90            Waterside Cafe  4ca2a6b3f832a1cd9b2e97e5                Café
# 96          Bon Appetit Cafe  4d50075b9ffc236a77eb14a7                Café
# 98                    Stadel  4ce160d9df986ea8c649ec16               Diner
#
#           lat        lng  Likes    Quality Food categories  Label
# 5   22.538357  88.351406     20  above avg          Indian      2
# 6   22.539091  88.365573     14  above avg     Other Asian      2
# 14  22.541290  88.350629     21  above avg       Beverages      2
# 30  22.546536  88.361654     21  above avg          Indian      2
# 38  22.546518  88.387213     20  above avg     Other Asian      2
# 39  22.545592  88.387475     20  above avg     Other Asian      2
# 49  22.501667  88.361787     14  above avg    Western food      2
# 51  22.513831  88.353231     15  above avg    Western food      2
# 64  22.519704  88.365422     20  above avg          Indian      2
# 69  22.577619  88.390439     14  above avg    Western food      2
# 85  22.568473  88.434431     21  above avg       Beverages      2
# 90  22.570363  88.405353     16  above avg    Western food      2
# 96  22.595683  88.406851     16  above avg    Western food      2
# 98  22.569257  88.411274     14  above avg          Indian      2

# %% [markdown]
# **Cluster 3:**<br>
# Venues Categories: Indian, Other Asian and Western foods dominate<br>
# Quality:All of them are **Excellent**

# %%
cluster3=food_venues.loc[food_venues['Label']==3]
cluster3['Food categories'].value_counts()
# Out:
# Indian          9
# Other Asian     3
# Western food    3
# Beverages       2
# Name: Food categories, dtype: int64

# %%
cluster3
# Out:
#                             name                        id  \
# 0                 The Blue Poppy  4d43fd7b4e5d370413f4e593
# 1                 Jai Hind Dhaba  4d050f03347da1cd0d012f8f
# 3   Balwant Singh's Eating House  4d1c6d5a7e10a35dcb13ff82
# 4                      Peter Cat  4c284edefe6e2d7f5417533c
# 9                       Nocturne  4d70225a9aac224bd12337ed
# 17                        Flurys  4befc8c03a002d7f386285a4
# 20            6 Ballygunge Place  4d54ed50c6edf04d1af5bea2
# 22                       Bar-B-Q  4e0b1e8422713e13018ee0a1
# 24                       Mocambo  4beebe513686c9b69bde246e
# 26                          Aqua  4bbf785db083a593d77fa3e9
# 36                      Big Boss  4dfa2b8aae60f95f8225b9c9
# 45               The Irish House  534fd97c498effb74edc096b
# 53           Chili's Grill & Bar  52b5503411d2be7ddd7aaa58
# 54                       Arsalan  4d3026dfa241f04d2878b127
# 56                        Olypub  4d7c82a186cfa1439d8ccba0
# 70                Mainland China  4c0651d9761ac9b60ab92074
# 95               Barbecue Nation  4d443e6b0349224b37f4f74e
#
#             categories        lat        lng  Likes    Quality  \
# 0     Asian Restaurant  22.548543  88.351353     23  excellent
# 1                Dhaba  22.533109  88.353268     48  excellent
# 3                Dhaba  22.537714  88.344220     74  excellent
# 4    Indian Restaurant  22.552365  88.352544    175  excellent
# 9            Nightclub  22.545078  88.357384     36  excellent
# 17              Bakery  22.552786  88.352625    151  excellent
# 20  Bengali Restaurant  22.527712  88.368677     39  excellent
# 22           BBQ Joint  22.553125  88.352625    100  excellent
# 24          Restaurant  22.553206  88.353296     80  excellent
# 26              Lounge  22.554734  88.352180     24  excellent
# 36  Chinese Restaurant  22.546493  88.388162     22  excellent
# 45           Irish Pub  22.539018  88.365570     22  excellent
# 53  Tex-Mex Restaurant  22.539151  88.365496     40  excellent
# 54  Mughlai Restaurant  22.543709  88.365994     35  excellent
# 56                 Pub  22.553551  88.351925     54  excellent
# 70  Chinese Restaurant  22.501652  88.361699     41  excellent
# 95   Indian Restaurant  22.568643  88.433139     40  excellent
#
#    Food categories  Label
# 0      Other Asian      3
# 1           Indian      3
# 3           Indian      3
# 4           Indian      3
# 9        Beverages      3
# 17          Indian      3
# 20          Indian      3
# 22    Western food      3
# 24          Indian      3
# 26          Indian      3
# 36     Other Asian      3
# 45    Western food      3
# 53    Western food      3
# 54          Indian      3
# 56       Beverages      3
# 70     Other Asian      3
# 95          Indian      3

# %% [markdown]
# ### DATA VISUALIZATION

# %% [markdown]
# The **food_venues** will be marked on folium map with circle markers:<br>
# <br>

# %% [markdown]
# |Cluster|Color|Quality|Food Category|
# |-------|-----|-------|-------------|
# |0|Red|Below Average|Indian and Western|
# |1|Violet|Poor|Indian|
# |2|Cyan|Above Average|Indian and Western|
# |3|Yellow|Excellent|Indian, Other Asian and Western|

# %%
map_Kolkata = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(k_clusters)
ys = [i+x+(i*x)**2 for i in range(k_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, long, poi, cluster in zip(food_venues['lat'], food_venues['lng'], food_venues['name'], food_venues['Label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=3,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_Kolkata)
       
map_Kolkata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, we will mark the **other_venues** inthe folium map<br>
# Color: light gray<br>
# Marker: Tooltip<br>
# icon: Arrow-down

# %%
for lat, long, poi in zip(other_venues['lat'], other_venues['lng'], other_venues['name']):
    label = folium.Popup(str(poi), parse_html=True)
    folium.Marker(
        [lat, long],
        popup=label,
        icon=folium.Icon(color='lightgray', icon='arrow-down')).add_to(map_Kolkata)
       
map_Kolkata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, we will show the **Top_Locations** dataframe to visualize the must-see places:
# Color: blue<br>
# Marker: Tooltip<br>
# icon: Bookmark

# %%
for lat, long, poi in zip(Top_Locations['Lat'], Top_Locations['Long'], Top_Locations['name']):
    label = folium.Popup(str(poi), parse_html=True)
    tooltip='Click me!'
    folium.Marker(
        [lat, long],
        popup=label,
        icon=folium.Icon(color='blue', icon='bookmark')).add_to(map_Kolkata)
       
map_Kolkata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
top_food=cluster3['name','categories','Likes','Quality']

# %% [markdown]
#                                                   Thanks for reviewing the notebook :)
